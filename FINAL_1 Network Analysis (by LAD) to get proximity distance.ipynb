# %% [raw]
# Source: https://notebooks.githubusercontent.com/view/ipynb?browser=chrome&color_mode=auto&commit=2dc07f9423ee25075fad5d82eaa9241329a07a06&device=unknown&enc_url=&logged_in=false&nwo=smmaurer%2Fcp255&path=07-street-networks%2Fshortest-paths.ipynb&platform=android&repository_id=235729329&repository_type=Repository&version=99

# %%
import shapely                 #needed to set geopandas geometry 
from shapely.wkt import loads  #needed to set geopandas geometry

import pandas as pd            #for DataFrame and analysis
import numpy as np
import geopandas as gpd        #for mapping and spatial aggregation

import matplotlib.pyplot as plt  #use matplotlib to modify the plots (e.g. make them larger) 
import seaborn as sb             #for data viz
import palettable.colorbrewer.sequential as pcs #for choropleth maps
import libpysal as lps
import statsmodels.formula.api as smf  #for regression
import scipy.stats as ss 
import pysal as ps
from pysal.model import spreg
from spreg import ols
from spreg import ML_Error
from spreg import ML_Lag

import os
import urllib
import zipfile
import sys
from libpysal.weights import Queen, Rook
import pysal.viz as viz
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')

import osmnx as ox
ox.config(log_file=True, log_console=True, use_cache=True)
import networkx as nx

# %%
sm = pd.read_csv("C:/Users/samue/OneDrive - King's College London/Desktop/KCL Y3/Dissertation/1 Datasets/Python/Supermarket (All).csv")

# %%
pwc = pd.read_csv("C:/Users/samue/OneDrive - King's College London/Desktop/KCL Y3/Dissertation/1 Datasets/Python/LSOA PWC.csv")

# %%
df = pd.read_csv("C:/Users/samue/OneDrive - King's College London/Desktop/KCL Y3/Dissertation/1 Datasets/Python/Master (LSOA).csv", encoding= "unicode_escape")

# %%
#creating geometry column in sm
#reproject to BNG

smgdf = gpd.GeoDataFrame(
    sm, geometry=gpd.points_from_xy(sm.X, sm.Y))
CRS = {'init': 'epsg:27700'}

smgdf = gpd.GeoDataFrame(smgdf, crs=CRS)

# %%
lsoa = gpd.read_file("C:/Users/samue/OneDrive - King's College London/Desktop/KCL Y3/Dissertation/1 Datasets/Python/LSOA.shp")

# %%
lsoa = lsoa.to_crs ({'init':'epsg:27700'})

# %%
#slicing SM data
sm1 = sm[(sm["LAD"]== "Enfield")]

# %%
sm1
# Out:
#          c          id     Tier                retailer postcode      LAD  \
# 263    979  1010015923   Budget                 Iceland  EN2 6TR  Enfield
# 268    984  1010007080   Budget                    Lidl  EN2 6TR  Enfield
# 273    989  1010007229   Budget                    Lidl  N18 2XZ  Enfield
# 285   1001  1010012790   Budget                    Aldi  EN1 1TH  Enfield
# 291   1007  1010000913   Budget                    Asda  N14 5PW  Enfield
# 292   1008  1010010905   Budget                 Iceland   N9 0HW  Enfield
# 293   1009  1010007232   Budget                    Lidl   N9 0TY  Enfield
# 295   1011  1010014120   Budget                    Lidl  EN3 6PS  Enfield
# 296   1012  1010000992   Budget                    Asda  EN3 4EF  Enfield
# 298   1014  1010000734   Budget                    Asda   N9 0AL  Enfield
# 1040  4573  1010004927      Mid                   Tesco  EN2 7AE  Enfield
# 1048  4581  1010003520      Mid              Sainsburys  EN1 1BA  Enfield
# 1049  4582  1010012742      Mid              Sainsburys  N13 5TW  Enfield
# 1061  4594  1010005278      Mid                   Tesco  N18 2XF  Enfield
# 1068  4601  1010013892      Mid              Sainsburys  EN2 0BX  Enfield
# 1080  4613  1010003087      Mid              Sainsburys  N21 1UJ  Enfield
# 1091  4624  1010004166      Mid                   Tesco  EN1 1RT  Enfield
# 1111  4644  1010002943      Mid              Sainsburys  EN1 1TH  Enfield
# 1112  4645  1010006242      Mid                   Tesco  N18 3HF  Enfield
# 1115  4648  1010004928      Mid                   Tesco  EN3 6GS  Enfield
# 1120  4653  1010006025      Mid                   Tesco  N14 4XA  Enfield
# 1128  4661  1010006188      Mid                   Tesco  EN3 4DP  Enfield
# 1129  4662  1010002283      Mid               Morrisons  EN1 1TW  Enfield
# 1133  4666  1010003652      Mid              Sainsburys  N11 1AH  Enfield
# 1134  4667  1010005272      Mid                   Tesco  N14 5PH  Enfield
# 1136  4669  1010006026      Mid                   Tesco  N21 2SA  Enfield
# 1142  4675  1010003522      Mid              Sainsburys  EN4 0DB  Enfield
# 1150  4683  1010005977      Mid                   Tesco  EN3 5UT  Enfield
# 1154  4687  1010003521      Mid              Sainsburys  EN2 6HU  Enfield
# 1163  4696  1010002412      Mid               Morrisons  N13 4YD  Enfield
# 1166  4699  1010003088      Mid              Sainsburys  N21 3RS  Enfield
# 1609  8387  1010019102  Premium       Marks and Spencer  N18 1QX  Enfield
# 1612  8390  1010010031  Premium  The Co-operative Group  EN3 5JG  Enfield
# 1619  8397  1010013511  Premium       Marks and Spencer  EN3 7NT  Enfield
# 1633  8411  1010010032  Premium  The Co-operative Group  EN2 0QU  Enfield
# 1637  8415  1010014483  Premium  The Co-operative Group  EN2 0JH  Enfield
# 1638  8416  1010006515  Premium                Waitrose  EN2 7AS  Enfield
# 1642  8420  1010001949  Premium       Marks and Spencer  EN1 3RR  Enfield
# 1644  8422  1010001421  Premium       Marks and Spencer  EN2 6SN  Enfield
# 1647  8425  1010010030  Premium  The Co-operative Group  EN2 0JW  Enfield
# 1653  8431  1010006632  Premium                Waitrose  EN2 6SN  Enfield
# 1659  8437  1010002009  Premium       Marks and Spencer  N14 6AQ  Enfield
# 1667  8445  1010014867  Premium                Waitrose  N21 2QP  Enfield
# 1668  8446  1010013539  Premium       Marks and Spencer  EN4 0DZ  Enfield
# 1680  8458  1010010033  Premium  The Co-operative Group  EN1 1XH  Enfield
#
#                 X            Y   LSOA11CD      LSOA11NM    LAD21CD  LAD21NM  \
# 263   532720.7832  196485.1540  E01001450  Enfield 015C  E09000010  Enfield
# 268   532873.1724  196374.5712  E01001450  Enfield 015C  E09000010  Enfield
# 273   534056.5127  192377.7986  E01001558  Enfield 033E  E09000010  Enfield
# 285   534527.4227  196863.3586  E01001513  Enfield 012F  E09000010  Enfield
# 291   529425.6526  194491.8186  E01001519  Enfield 020D  E09000003   Barnet
# 292   534639.2727  193663.0086  E01001429  Enfield 030D  E09000010  Enfield
# 293   534404.2127  193529.5886  E01001429  Enfield 030D  E09000010  Enfield
# 295   535533.6009  198833.9504  E01001547  Enfield 002C  E09000010  Enfield
# 296   535313.0027  195442.7286  E01001502  Enfield 018D  E09000010  Enfield
# 298   534423.7227  193301.8386  E01001429  Enfield 030D  E09000010  Enfield
# 1040  532131.3327  196725.0286  E01001472  Enfield 010D  E09000010  Enfield
# 1048  533700.9827  195437.2186  E01001406  Enfield 015B  E09000010  Enfield
# 1049  531183.7927  192925.8986  E01001498  Enfield 029B  E09000010  Enfield
# 1061  534068.1427  192229.5086  E01001558  Enfield 033E  E09000010  Enfield
# 1068  532911.4127  197833.5986  E01001411  Enfield 004B  E09000010  Enfield
# 1080  530790.0027  195801.9986  E01001522  Enfield 019B  E09000010  Enfield
# 1091  533149.5127  196443.5186  E01001512  Enfield 015D  E09000010  Enfield
# 1111  534464.8727  196586.8786  E01001513  Enfield 012F  E09000010  Enfield
# 1112  535241.0027  191933.9986  E01001559  Enfield 033F  E09000010  Enfield
# 1115  537266.7427  198530.3986  E01033150  Enfield 003G  E09000010  Enfield
# 1120  529463.7727  196020.7186  E01001419  Enfield 020A  E09000010  Enfield
# 1128  535170.9327  196161.2186  E01001507  Enfield 012D  E09000010  Enfield
# 1129  534365.6327  196141.5786  E01001511  Enfield 016D  E09000010  Enfield
# 1133  529165.4926  192481.8186  E01001534  Enfield 032E  E09000003   Barnet
# 1134  529569.8526  194352.8586  E01001519  Enfield 020D  E09000003   Barnet
# 1136  532025.2627  194425.6086  E01001402  Enfield 021D  E09000010  Enfield
# 1142  528231.9426  195996.6386  E01001415  Enfield 011A  E09000003   Barnet
# 1150  535440.1327  198138.6486  E01001441  Enfield 006B  E09000010  Enfield
# 1154  532901.7327  195850.1486  E01001450  Enfield 015C  E09000010  Enfield
# 1163  530913.0027  192666.9986  E01001501  Enfield 036E  E09000010  Enfield
# 1166  531714.0027  193999.9986  E01001570  Enfield 026E  E09000010  Enfield
# 1609  533474.7587  192205.8369  E01032574  Enfield 037E  E09000010  Enfield
# 1612  535188.8662  197189.1225  E01001439  Enfield 006A  E09000010  Enfield
# 1619  536360.4127  197202.2386  E01001438  Enfield 007E  E09000010  Enfield
# 1633  531934.2580  197841.7225  E01001540  Enfield 008C  E09000010  Enfield
# 1637  532462.3627  197837.9263  E01001408  Enfield 004A  E09000010  Enfield
# 1638  532054.0027  196682.9986  E01001457  Enfield 010A  E09000010  Enfield
# 1642  534505.6927  196861.2986  E01001513  Enfield 012F  E09000010  Enfield
# 1644  532762.4798  196435.9270  E01001451  Enfield 017A  E09000010  Enfield
# 1647  532762.3248  197860.7777  E01001411  Enfield 004B  E09000010  Enfield
# 1653  532636.6285  196506.0432  E01001450  Enfield 015C  E09000010  Enfield
# 1659  529843.5027  194417.1186  E01001519  Enfield 020D  E09000003   Barnet
# 1667  532022.0754  194664.7547  E01001456  Enfield 022A  E09000010  Enfield
# 1668  528077.4226  196438.8486  E01001415  Enfield 011A  E09000003   Barnet
# 1680  533897.8036  195557.5336  E01001406  Enfield 015B  E09000010  Enfield
#
#       Unnamed: 12 Unnamed: 13
# 263           NaN   E01000271
# 268           NaN   E01000174
# 273           NaN   E01004653
# 285           NaN   E01002883
# 291           NaN   E01002835
# 292           NaN   E01004609
# 293           NaN   E01001953
# 295           NaN   E01001857
# 296           NaN   E01002820
# 298           NaN   E01004652
# 1040          NaN         NaN
# 1048          NaN         NaN
# 1049          NaN         NaN
# 1061          NaN         NaN
# 1068          NaN         NaN
# 1080          NaN         NaN
# 1091          NaN         NaN
# 1111          NaN         NaN
# 1112          NaN         NaN
# 1115          NaN         NaN
# 1120          NaN         NaN
# 1128          NaN         NaN
# 1129          NaN         NaN
# 1133          NaN         NaN
# 1134          NaN         NaN
# 1136          NaN         NaN
# 1142          NaN         NaN
# 1150          NaN         NaN
# 1154          NaN         NaN
# 1163          NaN         NaN
# 1166          NaN         NaN
# 1609          NaN         NaN
# 1612          NaN         NaN
# 1619          NaN         NaN
# 1633          NaN         NaN
# 1637          NaN         NaN
# 1638          NaN         NaN
# 1642          NaN         NaN
# 1644          NaN         NaN
# 1647          NaN         NaN
# 1653          NaN         NaN
# 1659          NaN         NaN
# 1667          NaN         NaN
# 1668          NaN         NaN
# 1680          NaN         NaN

# %%
pwc.columns.values
# Out:
# array(['X', 'Y', 'objectid', 'lsoa11cd', 'lsoa11nm', 'LAD', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'], dtype=object)

# %%
#slicing PWC data
pwc1 = pwc[(pwc["LAD"]== "Enfield")]

# %%
# configure the place , network type , trip times , and travel speed
place_name = "London Borough of Enfield, London, England"
network_type = 'drive'

# %%
G = ox.graph.graph_from_place (place_name, network_type=network_type)

# %%
# project the network to the same CRS
G = ox.projection.project_graph (G, to_crs ={'init':'epsg:27700'})
gdf_nodes = ox.utils_graph.graph_to_gdfs (G, edges = False)

# %%
fig, ax = ox.plot.plot_graph(G, figsize=(8,8), node_size=0)

# %%
orig_df = pwc1[["lsoa11cd", "lsoa11nm", "X", "Y"]]

# %%
dest_df = sm1[["Tier", "retailer", "X", "Y"]]

# %%
# OPTION 2: use a strongly (instead of weakly) connected graph
Gs = ox.utils_graph.get_largest_component(G, strongly=True)

# %%
def nearest_node(row):
   return ox.get_nearest_node(Gs, (row.Y, row.X))

orig_df['orig_node'] = orig_df.apply(nearest_node, axis=1)  # axis=1 means do row-wise calculations (not column-wise)

orig_df
# Out:
#        lsoa11cd      lsoa11nm           X           Y   orig_node
# 42    E01001426  Enfield 030B  534645.379  192979.298    25420606
# 43    E01001427  Enfield 030C  534845.194  192503.048   689963252
# 44    E01001424  Enfield 030A  534137.000  193417.697    26002021
# 45    E01001425  Enfield 027B  534060.738  192836.942   689963398
# 46    E01001422  Enfield 011D  526305.730  197827.742    19192366
# ...         ...           ...         ...         ...         ...
# 4757  E01001553  Enfield 037B  532910.443  191850.729    25549935
# 4760  E01001485  Enfield 025B  534685.743  193798.586   251879817
# 4775  E01001531  Enfield 028B  530499.904  193598.495  7727529333
# 4814  E01001521  Enfield 028A  529791.295  193818.760  8674360798
# 4815  E01001528  Enfield 032B  529048.289  192154.418    21556591
#
# [183 rows x 5 columns]

# %%
def nearest_node(row):
   return ox.get_nearest_node(Gs, (row.Y, row.X))

dest_df['dest_node'] = dest_df.apply(nearest_node, axis=1)  # axis=1 means do row-wise calculations (not column-wise)

dest_df
# Out:
#          Tier                retailer            X            Y   dest_node
# 624       Mid                   Tesco  533536.8626  181260.5385  6110164647
# 627       Mid              Sainsburys  531670.1126  180983.6885  5177397824
# 629       Mid              Sainsburys  532344.4726  180968.8385  1938819320
# 642       Mid              Sainsburys  533239.0026  180936.5785  1547013704
# 647       Mid                   Tesco  532146.2526  181316.2285    20965797
# 657       Mid                   Tesco  531628.7026  181008.3185  4367041962
# 660       Mid                   Tesco  532957.4626  181313.0885   250549587
# 661       Mid              Sainsburys  533022.5326  181142.3385      107587
# 666       Mid                   Tesco  532987.0026  180809.9985      107627
# 669       Mid                   Tesco  533290.7226  181556.5585  3673602988
# 672       Mid                   Tesco  531626.7126  181469.1885    21686573
# 673       Mid              Sainsburys  531467.5226  181157.4985  4689775126
# 676       Mid              Sainsburys  532714.3526  180878.3385    25161360
# 678       Mid                   Tesco  531737.1826  181620.6685    25496857
# 683       Mid              Sainsburys  532001.3826  181271.4885    20965799
# 695       Mid              Sainsburys  532808.1926  181036.5785    24950107
# 696       Mid                   Tesco  533787.0126  180984.5685   283062108
# 704       Mid                   Tesco  532517.8026  181122.4985  5090420610
# 712       Mid              Sainsburys  531320.8284  181544.3554    21578461
# 1368  Premium       Marks and Spencer  532622.5926  180889.6785    25067400
# 1374  Premium       Marks and Spencer  533081.6054  181286.7631  1014649631
# 1375  Premium       Marks and Spencer  533030.1526  180970.9285  5335245256
# 1378  Premium       Marks and Spencer  533150.2995  181663.6808  2254629351
# 1382  Premium  The Co-operative Group  533458.4854  181099.5840    25475770
# 1383  Premium  The Co-operative Group  532118.1826  181242.6485    20965803
# 1384  Premium       Marks and Spencer  533428.3126  180934.0385  1547392771
# 1396  Premium       Marks and Spencer  531906.6226  181169.8685  1163955034
# 1406  Premium                Waitrose  532882.3326  180740.4885      107632
# 1410  Premium       Marks and Spencer  531612.2573  181190.8993      237908
# 1413  Premium  The Co-operative Group  532660.6121  181358.4655    21990628
# 1415  Premium       Marks and Spencer  532256.2426  181176.5785    25632862
# 1427  Premium  The Co-operative Group  533654.7361  180872.5392  4832472797
# 1428  Premium                Waitrose  532622.4426  180963.6485      107637

# %%
orig_list = []
dest_list = []

for o in orig_df.orig_node:
    for d in dest_df.dest_node:
        orig_list.append(o)
        dest_list.append(d)

all_ods = pd.DataFrame({'o_node': orig_list, 'd_node': dest_list})

all_ods
# Out:
#           o_node      d_node
# 0     2472018646  1569016999
# 1     2472018646      101899
# 2     2472018646  1569016984
# 3     2472018646  2833955766
# 4     2472018646    25468948
# ...          ...         ...
# 9571   772159872    26618344
# 9572   772159872  2213538538
# 9573   772159872      107895
# 9574   772159872      110105
# 9575   772159872   873822583
#
# [9576 rows x 2 columns]

# %%
def distance(row):
    return nx.shortest_path_length(Gs, source=row.o_node, target=row.d_node, weight='length')

all_ods['dist'] = all_ods.apply(distance, axis=1)

all_ods
# Out:
#           o_node      d_node      dist
# 0     2472018646  1569016999  1297.585
# 1     2472018646      101899   833.116
# 2     2472018646  1569016984  1285.406
# 3     2472018646  2833955766  5113.007
# 4     2472018646    25468948  3522.700
# ...          ...         ...       ...
# 9571   772159872    26618344  1252.154
# 9572   772159872  2213538538  2674.873
# 9573   772159872      107895  3662.714
# 9574   772159872      110105  3112.666
# 9575   772159872   873822583  2096.147
#
# [9576 rows x 3 columns]

# %%
#Sorting to find nearest supermarket
df = all_ods.sort_values(by='dist', ascending=True)
df = df.drop_duplicates(subset='o_node', keep="first")

# %%
df.to_csv('Richmond upon Thames.csv')

# %%
orig_df.to_csv("Enfield Orig NodeCoordinates.csv")

# %%
#for matching of coordinates to origin node points
dest_df.to_csv('City of London supermarket.csv')
